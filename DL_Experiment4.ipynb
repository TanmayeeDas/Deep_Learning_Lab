# %% [markdown]
# ## Name: Tanmayee Das
# ## Roll number: 25/AFI/27

# %% [markdown]
# # 1. Importing libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models

# %% [markdown]
# # 2. Using GPU

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # 3. Dataset extraction (cifar-10)

# %%
transform_cifar = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# %%
train_cifar = datasets.CIFAR10(
    root="./data",
    train=True,
    transform=transform_cifar,
    download=True
)

test_cifar = datasets.CIFAR10(
    root="./data",
    train=False,
    transform=transform_cifar,
    download=True
)

train_loader_cifar = DataLoader(train_cifar, batch_size=64, shuffle=True)
test_loader_cifar = DataLoader(test_cifar, batch_size=64, shuffle=False)
# Out:
# 100%|██████████| 170M/170M [00:05<00:00, 31.4MB/s]

# %% [markdown]
# # 4. CNN Architecture

# %%
class CNN(nn.Module):
    def __init__(self, activation_fn):
        super(CNN, self).__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            activation_fn,
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            activation_fn,
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 8 * 8, 256),
            activation_fn,
            nn.Dropout(0.5),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# # 5. Weight initialization techniques

# %%
def initialize_weights(model, init_type):
    for m in model.modules():
        if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
            if init_type == "xavier":
                nn.init.xavier_uniform_(m.weight)
            elif init_type == "kaiming":
                nn.init.kaiming_uniform_(m.weight, nonlinearity="relu")
            elif init_type == "random":
                nn.init.normal_(m.weight, mean=0, std=0.01)

# %% [markdown]
# # 6. Activation functions

# %%
activations = {
    "relu": nn.ReLU(),
    "tanh": nn.Tanh(),
    "leaky_relu": nn.LeakyReLU(0.01)
}

# %% [markdown]
# # 7. Optimizer techniques

# %%
def get_optimizer(optimizer_name, model):
    if optimizer_name == "sgd":
        return optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
    elif optimizer_name == "adam":
        return optim.Adam(model.parameters(), lr=0.001)
    elif optimizer_name == "rmsprop":
        return optim.RMSprop(model.parameters(), lr=0.001)

# %% [markdown]
# # 8. Training function

# %%
def train(model, train_loader, test_loader, optimizer, criterion, epochs=10):
    train_losses = []
    test_accuracies = []

    for epoch in range(epochs):
        model.train()
        running_loss = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_loss = running_loss / len(train_loader)
        train_losses.append(avg_loss)

        acc = evaluate(model, test_loader)
        test_accuracies.append(acc)

        print(f"Epoch [{epoch+1}/{epochs}]  Loss: {avg_loss:.4f}  Accuracy: {acc:.2f}%")

    return train_losses, test_accuracies

# %% [markdown]
# # 9. Evaluation function

# %%
def evaluate(model, test_loader):
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    return accuracy

# %% [markdown]
# # 9. Looping for every different variation

# %%
history = {}
models = {}

for act_name, act_fn in activations.items():
    for init in ["xavier", "kaiming", "random"]:
        for opt in ["sgd", "adam", "rmsprop"]:
            key = (act_name, init, opt)
            print(f"\nTraining Model: {key}")

            model = CNN(act_fn).to(device)
            initialize_weights(model, init)

            optimizer = get_optimizer(opt, model)
            criterion = nn.CrossEntropyLoss()

            losses, accuracies = train(
                model,
                train_loader_cifar,
                test_loader_cifar,
                optimizer,
                criterion,
                epochs=20
            )

            models[key] = model
            history[key] = {
                "loss": losses,
                "accuracy": accuracies
            }
# Out:
# Training Model: ('relu', 'xavier', 'sgd')
# Epoch [1/20]  Loss: 1.8264  Accuracy: 46.55%
# Epoch [2/20]  Loss: 1.5518  Accuracy: 52.36%
# Epoch [3/20]  Loss: 1.3810  Accuracy: 58.36%
# Epoch [4/20]  Loss: 1.2425  Accuracy: 61.63%
# Epoch [5/20]  Loss: 1.1528  Accuracy: 62.91%
# Epoch [6/20]  Loss: 1.0995  Accuracy: 65.79%
# Epoch [7/20]  Loss: 1.0448  Accuracy: 66.28%
# Epoch [8/20]  Loss: 1.0186  Accuracy: 69.18%
# Epoch [9/20]  Loss: 0.9887  Accuracy: 69.19%
# Epoch [10/20]  Loss: 0.9641  Accuracy: 69.92%
# Epoch [11/20]  Loss: 0.9369  Accuracy: 69.81%
# Epoch [12/20]  Loss: 0.9205  Accuracy: 70.58%
# Epoch [13/20]  Loss: 0.9105  Accuracy: 71.58%
# Epoch [14/20]  Loss: 0.8947  Accuracy: 71.27%
# Epoch [15/20]  Loss: 0.8746  Accuracy: 73.07%
# Epoch [16/20]  Loss: 0.8657  Accuracy: 71.99%
# Epoch [17/20]  Loss: 0.8520  Accuracy: 72.82%
# Epoch [18/20]  Loss: 0.8345  Accuracy: 73.93%
# Epoch [19/20]  Loss: 0.8316  Accuracy: 73.35%
# Epoch [20/20]  Loss: 0.8150  Accuracy: 73.70%
#
# Training Model: ('relu', 'xavier', 'adam')
# Epoch [1/20]  Loss: 1.7861  Accuracy: 49.84%
# Epoch [2/20]  Loss: 1.4652  Accuracy: 54.40%
# Epoch [3/20]  Loss: 1.3294  Accuracy: 60.18%
# Epoch [4/20]  Loss: 1.2433  Accuracy: 62.54%
# Epoch [5/20]  Loss: 1.1818  Accuracy: 64.22%
# Epoch [6/20]  Loss: 1.1179  Accuracy: 66.87%
# Epoch [7/20]  Loss: 1.0930  Accuracy: 67.43%
# Epoch [8/20]  Loss: 1.0527  Accuracy: 68.16%
# Epoch [9/20]  Loss: 1.0307  Accuracy: 69.52%
# Epoch [10/20]  Loss: 0.9988  Accuracy: 70.14%
# Epoch [11/20]  Loss: 0.9815  Accuracy: 70.71%
# Epoch [12/20]  Loss: 0.9606  Accuracy: 70.72%
# Epoch [13/20]  Loss: 0.9400  Accuracy: 71.52%
# Epoch [14/20]  Loss: 0.9250  Accuracy: 72.74%
# Epoch [15/20]  Loss: 0.9052  Accuracy: 72.67%
# Epoch [16/20]  Loss: 0.8909  Accuracy: 73.54%
# Epoch [17/20]  Loss: 0.8794  Accuracy: 73.25%
# Epoch [18/20]  Loss: 0.8578  Accuracy: 74.06%
# Epoch [19/20]  Loss: 0.8409  Accuracy: 74.20%
# Epoch [20/20]  Loss: 0.8366  Accuracy: 74.76%
#
# Training Model: ('relu', 'xavier', 'rmsprop')
# Epoch [1/20]  Loss: 1.9441  Accuracy: 45.37%
# Epoch [2/20]  Loss: 1.5422  Accuracy: 53.75%
# Epoch [3/20]  Loss: 1.4072  Accuracy: 57.42%
# Epoch [4/20]  Loss: 1.3165  Accuracy: 58.51%
# Epoch [5/20]  Loss: 1.2564  Accuracy: 61.18%
# Epoch [6/20]  Loss: 1.2064  Accuracy: 62.02%
# Epoch [7/20]  Loss: 1.1600  Accuracy: 65.65%
# Epoch [8/20]  Loss: 1.1149  Accuracy: 62.99%
# Epoch [9/20]  Loss: 1.0843  Accuracy: 63.79%
# Epoch [10/20]  Loss: 1.0604  Accuracy: 64.97%
# Epoch [11/20]  Loss: 1.0156  Accuracy: 68.27%
# Epoch [12/20]  Loss: 0.9984  Accuracy: 64.14%
# Epoch [13/20]  Loss: 0.9749  Accuracy: 68.24%
# Epoch [14/20]  Loss: 0.9539  Accuracy: 70.06%
# Epoch [15/20]  Loss: 0.9316  Accuracy: 71.31%
# Epoch [16/20]  Loss: 0.9178  Accuracy: 68.50%
# Epoch [17/20]  Loss: 0.9017  Accuracy: 66.52%
# Epoch [18/20]  Loss: 0.8844  Accuracy: 70.35%
# Epoch [19/20]  Loss: 0.8695  Accuracy: 71.05%
# Epoch [20/20]  Loss: 0.8501  Accuracy: 72.97%
#
# Training Model: ('relu', 'kaiming', 'sgd')
# Epoch [1/20]  Loss: 1.8380  Accuracy: 44.25%
# Epoch [2/20]  Loss: 1.5360  Accuracy: 53.33%
# Epoch [3/20]  Loss: 1.3602  Accuracy: 57.77%
# Epoch [4/20]  Loss: 1.2312  Accuracy: 62.00%
# Epoch [5/20]  Loss: 1.1597  Accuracy: 64.81%
# Epoch [6/20]  Loss: 1.1041  Accuracy: 65.23%
# Epoch [7/20]  Loss: 1.0679  Accuracy: 67.66%
# Epoch [8/20]  Loss: 1.0322  Accuracy: 68.36%
# Epoch [9/20]  Loss: 1.0014  Accuracy: 67.84%
# Epoch [10/20]  Loss: 0.9808  Accuracy: 69.54%
# Epoch [11/20]  Loss: 0.9588  Accuracy: 69.74%
# Epoch [12/20]  Loss: 0.9356  Accuracy: 70.63%
# Epoch [13/20]  Loss: 0.9178  Accuracy: 71.41%
# Epoch [14/20]  Loss: 0.9051  Accuracy: 72.66%
# Epoch [15/20]  Loss: 0.8877  Accuracy: 71.84%
# Epoch [16/20]  Loss: 0.8789  Accuracy: 72.16%
# Epoch [17/20]  Loss: 0.8644  Accuracy: 72.34%
# Epoch [18/20]  Loss: 0.8530  Accuracy: 73.77%
# Epoch [19/20]  Loss: 0.8449  Accuracy: 74.15%
# Epoch [20/20]  Loss: 0.8349  Accuracy: 73.05%
#
# Training Model: ('relu', 'kaiming', 'adam')
# Epoch [1/20]  Loss: 1.8180  Accuracy: 49.23%
# Epoch [2/20]  Loss: 1.4970  Accuracy: 53.26%
# Epoch [3/20]  Loss: 1.3603  Accuracy: 59.57%
# Epoch [4/20]  Loss: 1.2758  Accuracy: 61.64%
# Epoch [5/20]  Loss: 1.2137  Accuracy: 63.42%
# Epoch [6/20]  Loss: 1.1653  Accuracy: 65.93%
# Epoch [7/20]  Loss: 1.1238  Accuracy: 66.52%
# Epoch [8/20]  Loss: 1.0828  Accuracy: 67.88%
# Epoch [9/20]  Loss: 1.0598  Accuracy: 68.37%
# Epoch [10/20]  Loss: 1.0314  Accuracy: 68.93%
# Epoch [11/20]  Loss: 1.0057  Accuracy: 69.58%
# Epoch [12/20]  Loss: 0.9816  Accuracy: 70.48%
# Epoch [13/20]  Loss: 0.9688  Accuracy: 70.82%
# Epoch [14/20]  Loss: 0.9497  Accuracy: 70.42%
# Epoch [15/20]  Loss: 0.9314  Accuracy: 71.83%
# Epoch [16/20]  Loss: 0.9189  Accuracy: 72.87%
# Epoch [17/20]  Loss: 0.9019  Accuracy: 72.93%
# Epoch [18/20]  Loss: 0.8859  Accuracy: 73.54%
# Epoch [19/20]  Loss: 0.8735  Accuracy: 72.80%
# Epoch [20/20]  Loss: 0.8599  Accuracy: 74.29%
#
# Training Model: ('relu', 'kaiming', 'rmsprop')
# Epoch [1/20]  Loss: 1.9765  Accuracy: 47.30%
# Epoch [2/20]  Loss: 1.5185  Accuracy: 52.75%
# Epoch [3/20]  Loss: 1.3703  Accuracy: 51.74%
# Epoch [4/20]  Loss: 1.2800  Accuracy: 60.44%
# Epoch [5/20]  Loss: 1.2180  Accuracy: 62.64%
# Epoch [6/20]  Loss: 1.1752  Accuracy: 64.38%
# Epoch [7/20]  Loss: 1.1295  Accuracy: 64.40%
# Epoch [8/20]  Loss: 1.0946  Accuracy: 66.26%
# Epoch [9/20]  Loss: 1.0590  Accuracy: 66.98%
# Epoch [10/20]  Loss: 1.0369  Accuracy: 68.10%
# Epoch [11/20]  Loss: 1.0151  Accuracy: 65.20%
# Epoch [12/20]  Loss: 0.9828  Accuracy: 68.57%
# Epoch [13/20]  Loss: 0.9689  Accuracy: 71.46%
# Epoch [14/20]  Loss: 0.9396  Accuracy: 68.50%
# Epoch [15/20]  Loss: 0.9190  Accuracy: 70.32%
# Epoch [16/20]  Loss: 0.8998  Accuracy: 71.47%
# Epoch [17/20]  Loss: 0.8862  Accuracy: 72.38%
# Epoch [18/20]  Loss: 0.8635  Accuracy: 72.85%
# Epoch [19/20]  Loss: 0.8542  Accuracy: 70.43%
# Epoch [20/20]  Loss: 0.8445  Accuracy: 74.06%
#
# Training Model: ('relu', 'random', 'sgd')
# Epoch [1/20]  Loss: 1.6936  Accuracy: 50.02%
# Epoch [2/20]  Loss: 1.3955  Accuracy: 58.07%
# Epoch [3/20]  Loss: 1.2280  Accuracy: 63.76%
# Epoch [4/20]  Loss: 1.1196  Accuracy: 64.50%
# Epoch [5/20]  Loss: 1.0486  Accuracy: 67.21%
# Epoch [6/20]  Loss: 1.0086  Accuracy: 68.62%
# Epoch [7/20]  Loss: 0.9723  Accuracy: 69.39%
# Epoch [8/20]  Loss: 0.9481  Accuracy: 70.45%
# Epoch [9/20]  Loss: 0.9272  Accuracy: 71.51%
# Epoch [10/20]  Loss: 0.9012  Accuracy: 71.02%
# Epoch [11/20]  Loss: 0.8848  Accuracy: 72.34%
# Epoch [12/20]  Loss: 0.8730  Accuracy: 71.19%
# Epoch [13/20]  Loss: 0.8496  Accuracy: 72.84%
# Epoch [14/20]  Loss: 0.8360  Accuracy: 71.98%
# Epoch [15/20]  Loss: 0.8305  Accuracy: 73.50%
# Epoch [16/20]  Loss: 0.8244  Accuracy: 73.98%
# Epoch [17/20]  Loss: 0.8121  Accuracy: 74.48%
# Epoch [18/20]  Loss: 0.8011  Accuracy: 72.73%
# Epoch [19/20]  Loss: 0.7944  Accuracy: 74.81%
# Epoch [20/20]  Loss: 0.7837  Accuracy: 74.90%
#
# Training Model: ('relu', 'random', 'adam')
# Epoch [1/20]  Loss: 1.5659  Accuracy: 54.18%
# Epoch [2/20]  Loss: 1.2993  Accuracy: 59.11%
# Epoch [3/20]  Loss: 1.1882  Accuracy: 64.14%
# Epoch [4/20]  Loss: 1.1247  Accuracy: 65.83%
# Epoch [5/20]  Loss: 1.0637  Accuracy: 67.05%
# Epoch [6/20]  Loss: 1.0286  Accuracy: 68.74%
# Epoch [7/20]  Loss: 0.9919  Accuracy: 69.38%
# Epoch [8/20]  Loss: 0.9696  Accuracy: 69.14%
# Epoch [9/20]  Loss: 0.9455  Accuracy: 70.24%
# Epoch [10/20]  Loss: 0.9230  Accuracy: 71.81%
# Epoch [11/20]  Loss: 0.9058  Accuracy: 72.06%
# Epoch [12/20]  Loss: 0.8855  Accuracy: 72.02%
# Epoch [13/20]  Loss: 0.8705  Accuracy: 73.07%
# Epoch [14/20]  Loss: 0.8613  Accuracy: 72.72%
# Epoch [15/20]  Loss: 0.8446  Accuracy: 72.83%
# Epoch [16/20]  Loss: 0.8249  Accuracy: 73.38%
# Epoch [17/20]  Loss: 0.8119  Accuracy: 73.64%
# Epoch [18/20]  Loss: 0.8041  Accuracy: 74.73%
# Epoch [19/20]  Loss: 0.7932  Accuracy: 74.05%
# Epoch [20/20]  Loss: 0.7854  Accuracy: 75.02%
#
# Training Model: ('relu', 'random', 'rmsprop')
# Epoch [1/20]  Loss: 1.6665  Accuracy: 47.71%
# Epoch [2/20]  Loss: 1.3550  Accuracy: 56.97%
# Epoch [3/20]  Loss: 1.2345  Accuracy: 57.75%
# Epoch [4/20]  Loss: 1.1650  Accuracy: 59.40%
# Epoch [5/20]  Loss: 1.1098  Accuracy: 62.93%
# Epoch [6/20]  Loss: 1.0635  Accuracy: 64.88%
# Epoch [7/20]  Loss: 1.0296  Accuracy: 61.76%
# Epoch [8/20]  Loss: 1.0019  Accuracy: 68.09%
# Epoch [9/20]  Loss: 0.9734  Accuracy: 68.83%
# Epoch [10/20]  Loss: 0.9505  Accuracy: 71.46%
# Epoch [11/20]  Loss: 0.9258  Accuracy: 71.38%
# Epoch [12/20]  Loss: 0.8999  Accuracy: 71.37%
# Epoch [13/20]  Loss: 0.8803  Accuracy: 70.78%
# Epoch [14/20]  Loss: 0.8577  Accuracy: 71.14%

# %% [markdown]
# # 10. Computing best config model

# %%
results = {}
for key, metrics in history.items():
    results[key] = max(metrics["accuracy"])

best_config = max(results, key=results.get)
best_accuracy = results[best_config]

print("Best Configuration:")
print(f"Activation   : {best_config[0]}")
print(f"Init Method  : {best_config[1]}")
print(f"Optimizer    : {best_config[2]}")
print(f"Accuracy (%) : {best_accuracy:.2f}")

# %% [markdown]
# # 11. Saving models

# %%
os.makedirs("saved_models", exist_ok=True)
for key, model in models.items():
    act, init, opt = key
    filename = f"cnn_{act}_{init}_{opt}.pth"
    torch.save(model.state_dict(), os.path.join("saved_models", filename))

# %%
# !zip -r models.zip /content/saved_models/*

# %% [markdown]
# # 12. Accuracy plot

# %%
plt.figure(figsize=(14, 6))
for key, metrics in history.items():
    plt.plot(metrics["accuracy"], label=str(key))

plt.title("Accuracy Comparison Across All CNN Configurations")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend(fontsize=7, loc="best")
plt.grid(True)
plt.show()

# %% [markdown]
# # 13. Loss plot

# %%
plt.figure(figsize=(14, 6))

for key, metrics in history.items():
    plt.plot(metrics["loss"], label=str(key))

plt.title("Training Loss Comparison Across All CNN Configurations")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(fontsize=7, loc="best")
plt.grid(True)
plt.show()

# %% [markdown]
# # 14. Resnet training

# %%
import torchvision.models as tv_models

resnet18 = tv_models.resnet18(pretrained=True)
for param in resnet18.parameters():
    param.requires_grad = False

resnet18.fc = nn.Linear(resnet18.fc.in_features, 10)
resnet18 = resnet18.to(device)

resnet_optimizer = optim.Adam(resnet18.fc.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

resnet_losses, resnet_accuracies = train(
    resnet18,
    train_loader_cifar,
    test_loader_cifar,
    resnet_optimizer,
    criterion,
    epochs=20
)

resnet_key = ("resnet18", "pretrained", "adam")

models[resnet_key] = resnet18
history[resnet_key] = {
    "loss": resnet_losses,
    "accuracy": resnet_accuracies
}

results[resnet_key] = max(resnet_accuracies)
torch.save(resnet18.state_dict(), "saved_models/resnet18_cifar10.pth")

print("ResNet-18 training complete.")
print(f"Best Accuracy: {results[resnet_key]:.2f}%")

# %% [markdown]
# # 15. Comparision (accuracy and loss)

# %%
best_cnn_history = history[best_config]
resnet_history = history[("resnet18", "pretrained", "adam")]

# %%
plt.figure(figsize=(8, 5))
plt.plot(best_cnn_history["accuracy"], label="Best CNN", linewidth=3)
plt.plot(resnet_history["accuracy"], label="ResNet-18", linewidth=3, linestyle="--")
plt.title("Accuracy Comparison: Best CNN vs ResNet-18")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(best_cnn_history["loss"], label="Best CNN", linewidth=3)
plt.plot(resnet_history["loss"], label="ResNet-18", linewidth=3, linestyle="--")
plt.title("Loss Comparison: Best CNN vs ResNet-18")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()
